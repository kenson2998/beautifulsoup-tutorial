# %%
import requests
from bs4 import BeautifulSoup as BS4
html = 'http://www.coffeearticle.com/archives/category/心靈雞湯'
headers = {'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1"}
re = requests.get(html, headers = headers)
print(re)
# Out:
# <Response [200]>

# %%
import requests
from bs4 import BeautifulSoup as BS4
html = 'http://www.coffeearticle.com/archives/category/心靈雞湯'
headers = {'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1"}
re = requests.get(html, headers = headers)

print(re.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]><html class="ie8"><![endif]-->
# <!--[if IE 9]><html class="ie9"><![endif]-->
# <!--[if gt IE 8]><!--> <html lang="zh-TW" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://ogp.me/ns/fb#"> <!--<![endif]-->
#
# <head>
#
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta name="viewport" content="user-scalable=yes, width=device-width, initial-scale=1.0, maximum-scale=1, minimum-scale=1">
#
# <!--[if lt IE 9]>
# 	<script src="http://www.coffeearticle.com/wp-content/themes/voice/js/html5.js"></script>
# <![endif]-->
#
# <title>心靈雞湯 &#8211; 一杯咖啡一篇文章</title>
# <link rel='dns-prefetch' href='//fonts.googleapis.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel="alternate" type="application/rss+xml" title="訂閱 一杯咖啡一篇文章 &raquo;" href="http://www.coffeearticle.com/feed" />
# <link rel="alternate" type="application/rss+xml" title="訂閱 一杯咖啡一篇文章 &raquo; 迴響" href="http://www.coffeearticle.com/comments/feed" />
# <link rel="alternate" type="application/rss+xml" title="訂閱 一杯咖啡一篇文章 &raquo; 心靈雞湯 分類" href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af/feed" />
# 		<script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/www.coffeearticle.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.9.8"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# 		<!-- managing ads with Advanced Ads – https://wpadvancedads.com/ --><script>
# 					advanced_ads_ready=function(){var fns=[],listener,doc=typeof document==="object"&&document,hack=doc&&doc.documentElement.doScroll,domContentLoaded="DOMContentLoaded",loaded=doc&&(hack?/^loaded|^c/:/^loaded|^i|^c/).test(doc.readyState);if(!loaded&&doc){listener=function(){doc.removeEventListener(domContentLoaded,listener);window.removeEventListener("load",listener);loaded=1;while(listener=fns.shift())listener()};doc.addEventListener(domContentLoaded,listener);window.addEventListener("load",listener)}return function(fn){loaded?setTimeout(fn,0):fns.push(fn)}}();
# 			</script><style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link rel='stylesheet' id='mks_shortcodes_simple_line_icons-css'  href='http://www.coffeearticle.com/wp-content/plugins/meks-flexible-shortcodes/css/simple-line/simple-line-icons.css?ver=1.3.1' type='text/css' media='screen' />
# <link rel='stylesheet' id='mks_shortcodes_css-css'  href='http://www.coffeearticle.com/wp-content/plugins/meks-flexible-shortcodes/css/style.css?ver=1.3.1' type='text/css' media='screen' />
# <link rel='stylesheet' id='spu-public-css-css'  href='http://www.coffeearticle.com/wp-content/plugins/popups/public/assets/css/public.css?ver=1.9.3.2' type='text/css' media='all' />
# <link rel='stylesheet' id='vce_font_0-css'  href='http://fonts.googleapis.com/css?family=Open+Sans%3A400&#038;subset=latin%2Clatin-ext&#038;ver=2.7' type='text/css' media='screen' />
# <link rel='stylesheet' id='vce_font_1-css'  href='http://fonts.googleapis.com/css?family=Roboto+Slab%3A400&#038;subset=latin%2Clatin-ext&#038;ver=2.7' type='text/css' media='screen' />
# <link rel='stylesheet' id='vce_style-css'  href='http://www.coffeearticle.com/wp-content/themes/voice/css/min.css?ver=2.7' type='text/css' media='screen, print' />
# <style id='vce_style-inline-css' type='text/css'>
# body, button, input, select, textarea{font-size: 2rem;}.vce-single .entry-headline p{font-size: 2.2rem;}.main-navigation a{font-size: rem;}.sidebar .widget-title{font-size: 2rem;}.sidebar .widget{font-size: 1.5rem;}.vce-featured-link-article{font-size: 5rem;}.vce-featured-grid-big.vce-featured-grid .vce-featured-link-article{font-size: 3.4rem;}.vce-featured-grid .vce-featured-link-article{font-size: 2.2rem;}h1 { font-size: 4.3rem; }h2 { font-size: 4rem; }h3 { font-size: 3.5rem; }h4 { font-size: 2.5rem; }h5 { font-size: 2rem; }h6 { font-size: 1.8rem; }.comment-reply-title, .main-box-title{font-size: 2.2rem;}h1.entry-title{font-size: 4.3rem;}.vce-lay-a .entry-title a{font-size: 3.4rem;}.vce-lay-b .entry-title{font-size: 2.4rem;}.vce-lay-c .entry-title, .vce-sid-none .vce-lay-c .entry-title{font-size: 2.2rem;}.vce-lay-d .entry-title{font-size: 1.5rem;}.vce-lay-e .entry-title{font-size: 1.4rem;}.vce-lay-f .entry-title{font-size: 1.4rem;}.vce-lay-g .entry-title a, .vce-lay-g .entry-title a:hover{font-size: 3rem;}.vce-lay-h .entry-title{font-size: 2.4rem;}.entry-meta div,.entry-meta div a,.vce-lay-g .meta-item,.vce-lay-c .meta-item{font-size: 1.5rem;}.vce-lay-d .meta-category a,.vce-lay-d .entry-meta div,.vce-lay-d .entry-meta div a,.vce-lay-e .entry-meta div,.vce-lay-e .entry-meta div a,.vce-lay-e .fn,.vce-lay-e .meta-item{font-size: 1.5rem;}body {background-color:#f0f0f0;}body,.mks_author_widget h3,.site-description,.meta-category a,textarea {font-family: 'Open Sans';font-weight: 400;}h1,h2,h3,h4,h5,h6,blockquote,.vce-post-link,.site-title,.site-title a,.main-box-title,.comment-reply-title,.entry-title a,.vce-single .entry-headline p,.vce-prev-next-link,.author-title,.mks_pullquote,.widget_rss ul li .rsswidget,#bbpress-forums .bbp-forum-title,#bbpress-forums .bbp-topic-permalink {font-family: 'Comic Sans MS', cursive;font-weight: 400;}.main-navigation a,.sidr a{font-family: 'Roboto Slab';font-weight: 400;}.vce-single .entry-content,.vce-single .entry-headline,.vce-single .entry-footer{width: 600px;}.vce-lay-a .lay-a-content{width: 600px;max-width: 600px;}.vce-page .entry-content,.vce-page .entry-title-page {width: 600px;}.vce-sid-none .vce-single .entry-content,.vce-sid-none .vce-single .entry-headline,.vce-sid-none .vce-single .entry-footer {width: 600px;}.vce-sid-none .vce-page .entry-content,.vce-sid-none .vce-page .entry-title-page,.error404 .entry-content {width: 600px;max-width: 600px;}body, button, input, select, textarea{color: #444444;}h1,h2,h3,h4,h5,h6,.entry-title a,.prev-next-nav a,#bbpress-forums .bbp-forum-title, #bbpress-forums .bbp-topic-permalink,.woocommerce ul.products li.product .price .amount{color: #232323;}a,.entry-title a:hover,.vce-prev-next-link:hover,.vce-author-links a:hover,.required,.error404 h4,.prev-next-nav a:hover,#bbpress-forums .bbp-forum-title:hover, #bbpress-forums .bbp-topic-permalink:hover,.woocommerce ul.products li.product h3:hover,.woocommerce ul.products li.product h3:hover mark,.main-box-title a:hover{color: #cf4d35;}.vce-square,.vce-main-content .mejs-controls .mejs-time-rail .mejs-time-current,button,input[type="button"],input[type="reset"],input[type="submit"],.vce-button,.pagination-wapper a,#vce-pagination .next.page-numbers,#vce-pagination .prev.page-numbers,#vce-pagination .page-numbers,#vce-pagination .page-numbers.current,.vce-link-pages a,#vce-pagination a,.vce-load-more a,.vce-slider-pagination .owl-nav > div,.vce-mega-menu-posts-wrap .owl-nav > div,.comment-reply-link:hover,.vce-featured-section a,.vce-lay-g .vce-featured-info .meta-category a,.vce-404-menu a,.vce-post.sticky .meta-image:before,#vce-pagination .page-numbers:hover,#bbpress-forums .bbp-pagination .current,#bbpress-forums .bbp-pagination a:hover,.woocommerce #respond input#submit,.woocommerce a.button,.woocommerce button.button,.woocommerce input.button,.woocommerce ul.products li.product .added_to_cart,.woocommerce #respond input#submit:hover,.woocommerce a.button:hover,.woocommerce button.button:hover,.woocom ...
# </style>
# <link rel='stylesheet' id='meks-ads-widget-css'  href='http://www.coffeearticle.com/wp-content/plugins/meks-easy-ads-widget/css/style.css?ver=2.0.4' type='text/css' media='all' />
# <link rel='stylesheet' id='meks-flickr-widget-css'  href='http://www.coffeearticle.com/wp-content/plugins/meks-simple-flickr-widget/css/style.css?ver=1.1.3' type='text/css' media='all' />
# <link rel='stylesheet' id='meks-social-widget-css'  href='http://www.coffeearticle.com/wp-content/plugins/meks-smart-social-widget/css/style.css?ver=1.3.5' type='text/css' media='all' />
# <link rel='stylesheet' id='meks-themeforest-widget-css'  href='http://www.coffeearticle.com/wp-content/plugins/meks-themeforest-smart-widget/css/style.css?ver=1.2' type='text/css' media='all' />
# <script type='text/javascript' src='http://www.coffeearticle.com/wp-includes/js/jquery/jquery.js?ver=1.12.4'></script>
# <script type='text/javascript' src='http://www.coffeearticle.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1'></script>
# <script type='text/javascript' src='http://www.coffeearticle.com/wp-content/plugins/meks-flexible-shortcodes/js/main.js?ver=1.3.1'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var pys_fb_pixel_options = {"woo":{"addtocart_enabled":false,"product_data":""},"gdpr":{"disable":false,"enable_before_consent":"1","ginger_enabled":false,"cookiebot_enabled":false}};
# var pys_events = [{"type":"init","name":"369878790102412","params":[]},{"type":"track","name":"PageView","params":{"domain":"www.coffeearticle.com"},"delay":0},{"type":"trackCustom","name":"\u9020\u8a2a\u7db2\u7ad95\u4ee5\u4e0a","params":{"post_type":"category","content_name":"\u5fc3\u9748\u96de\u6e6f","post_id":16,"domain":"www.coffeearticle.com"},"delay":5}];
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://www.coffeearticle.com/wp-content/plugins/pixelyoursite/js/public.js?ver=5.3.2'></script>
# <link rel='https://api.w.org/' href='http://www.coffeearticle.com/wp-json/' />
# <link rel="EditURI" type="application/rsd+xml" title="RSD" href="http://www.coffeearticle.com/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="http://www.coffeearticle.com/wp-includes/wlwmanifest.xml" />
# <meta name="generator" content="WordPress 4.9.8" />
# 			<meta property="fb:pages" content="1441185349481496" />
# 							<meta property="ia:markup_url" content="http://www.coffeearticle.com/archives/27902?ia_markup=1" />
# 				<script type="text/javascript">
# <!--
# /******************************************************************************
# ***   COPY PROTECTED BY http://chetangole.com/blog/wp-copyprotect/   version 3.1.0 ****
# ******************************************************************************/
# function clickIE4(){
# if (event.button==2){
# return false;
# }
# }
# function clickNS4(e){
# if (document.layers||document.getElementById&&!document.all){
# if (e.which==2||e.which==3){
# return false;
# }
# }
# }
#
# if (document.layers){
# document.captureEvents(Event.MOUSEDOWN);
# document.onmousedown=clickNS4;
# }
# else if (document.all&&!document.getElementById){
# document.onmousedown=clickIE4;
# }
#
# document.oncontextmenu=new Function("return false")
# // -->
# </script>
#
# <script type="text/javascript">
# /******************************************************************************
# ***   COPY PROTECTED BY http://chetangole.com/blog/wp-copyprotect/   version 3.1.0 ****
# ******************************************************************************/
# function disableSelection(target){
# if (typeof target.onselectstart!="undefined") //For IE
# 	target.onselectstart=function(){return false}
# else if (typeof target.style.MozUserSelect!="undefined") //For Firefox
# 	target.style.MozUserSelect="none"
# else //All other route (For Opera)
# 	target.onmousedown=function(){return false}
# target.style.cursor = "default"
# }
# </script>
#
# 		<!-- Facebook Pixel code is added on this page by PixelYourSite FREE v5.3.2 plugin. You can test it with Pixel Helper Chrome Extension. -->
#
# 		<link rel="shortcut icon" href="http://www.coffeearticle.com/wp-content/uploads/2018/06/favicon-194x194.png" type="image/x-icon" />		<style type="text/css" id="wp-custom-css">
# 			p {
#     margin-bottom: 20px;
#     word-wrap: break-word;
#     FONT-SIZE: 16px;
# }		</style>
#
# <!-- START - Open Graph for Facebook, Google+ and Twitter Card Tags 2.2.4.2 -->
#  <!-- Facebook Open Graph -->
#   <meta property="og:locale" content="zh_TW"/>
#   <meta property="og:site_name" content="一杯咖啡一篇文章"/>
#   <meta property="og:title" content="心靈雞湯"/>
#   <meta property="og:url" content="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af"/>
#   <meta property="og:type" content="article"/>
#   <meta property="og:description" content="心靈雞湯"/>
#   <meta property="article:publisher" content="https://www.facebook.com/coffeearticle/"/>
#   <meta property="fb:admins" content="https://www.facebook.com/weiche.hsu.90"/>
#  <!-- Google+ / Schema.org -->
#   <meta itemprop="name" content="心靈雞湯"/>
#   <meta itemprop="headline" content="心靈雞湯"/>
#   <meta itemprop="description" content="心靈雞湯"/>
#   <!--<meta itemprop="publisher" content="一杯咖啡一篇文章"/>--> <!-- To solve: The attribute publisher.itemtype has an invalid value -->
#  <!-- Twitter Cards -->
#   <meta name="twitter:title" content="心靈雞湯"/>
#   <meta name="twitter:url" content="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af"/>
#   <meta name="twitter:description" content="心靈雞湯"/>
#   <meta name="twitter:card" content="summary_large_image"/>
#  <!-- SEO -->
#  <!-- Misc. tags -->
#  <!-- is_category -->
# <!-- END - Open Graph for Facebook, Google+ and Twitter Card Tags 2.2.4.2 -->
#
#
# 	<script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({
#           google_ad_client: "ca-pub-9001105210796177",
#           enable_page_level_ads: true
#      });
# </script>
#
# </head>
#
# <body class="archive category category-16 chrome vce-sid-right">
#
# <div id="vce-main">
#
# <header id="header" class="main-header">
# 	<div class="top-header">
# 	<div class="container">
#
# 					<div class="vce-wrap-left">
# 					<ul id="vce_top_navigation_menu" class="top-nav-menu"><li id="menu-item-24566" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-24566"><a href="http://www.coffeearticle.com/%e9%a6%96%e9%a0%81">首頁</a></li>
# </ul>			</div>
#
# 					<div class="vce-wrap-right">
# 					<div class="menu-social-menu-container"><ul id="vce_social_menu" class="soc-nav-menu"><li id="menu-item-24385" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-24385"><a href="https://www.facebook.com/coffeearticle/"><span class="vce-social-name">Facebook</span></a></li>
# <li id="menu-item-24390" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-24390"><a href="https://www.instagram.com/coffeearticle/"><span class="vce-social-name">Instagram</span></a></li>
# </ul></div>			</div>
#
#
#
#
# 	</div>
# </div><div class="container header-1-wrapper header-main-area">
# 		<div class="vce-res-nav">
# 	<a class="vce-responsive-nav" href="#sidr-main"><i class="fa fa-bars"></i></a>
# </div>
# <div class="site-branding">
#
#
# 	<span class="site-title">
# 		<a href="http://www.coffeearticle.com/" title="一杯咖啡一篇文章" class="has-logo"><img src="http://www.coffeearticle.com/wp-content/uploads/2018/06/未命名-1-01.png" alt="一杯咖啡一篇文章" /></a>
# 	</span>
#
# <span class="site-description"></span>
#
#
# </div></div>
#
# <div class="header-bottom-wrapper">
# 	<div class="container">
# 		<nav id="site-navigation" class="main-navigation" role="navigation">
# 	<ul id="vce_main_navigation_menu" class="nav-menu"><li id="menu-item-24436" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-24436"><a href="http://www.coffeearticle.com/">首頁</a><li id="menu-item-24553" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24553 vce-cat-4"><a href="http://www.coffeearticle.com/archives/category/cafe%e8%8b%a6%e6%be%80">勵志感人</a><li id="menu-item-24540" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24540 vce-cat-13"><a href="http://www.coffeearticle.com/archives/category/cafe%e6%84%9f%e6%83%85">愛情故事</a><li id="menu-item-24541" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24541 vce-cat-6"><a href="http://www.coffeearticle.com/archives/category/cafe%e9%81%8b%e5%8b%a2">星座運勢</a><li id="menu-item-24542" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24542 vce-cat-5"><a href="http://www.coffeearticle.com/archives/category/cafe%e7%94%9f%e6%b4%bb">婚姻家庭</a><li id="menu-item-24543" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24543 vce-cat-12"><a href="http://www.coffeearticle.com/archives/category/cafe%e8%81%b7%e5%a0%b4">職場人生</a><li id="menu-item-24544" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24544 vce-cat-14"><a href="http://www.coffeearticle.com/archives/category/%e8%b6%a3%e5%91%b3%e6%b8%ac%e9%a9%97">趣味測驗</a><li id="menu-item-24545" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24545 vce-cat-7"><a href="http://www.coffeearticle.com/archives/category/cafe%e5%81%a5%e5%ba%b7">健康養生</a><li id="menu-item-24546" class="menu-item menu-item-type-taxonomy menu-item-object-category current-menu-item menu-item-24546 vce-cat-16"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af">心靈雞湯</a><li id="menu-item-24547" class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24547 vce-cat-8"><a href="http://www.coffeearticle.com/archives/category/cafe%e5%af%b5%e7%89%a9">寵物知識</a><li class="search-header-wrap"><a class="search_header" href="javascript:void(0)"><i class="fa fa-search"></i></a><ul class="search-header-form-ul"><li><form class="search-header-form" action="http://www.coffeearticle.com/" method="get">
# 							<input name="s" class="search-input" size="20" type="text" value="Type here to search..." onfocus="(this.value == 'Type here to search...') && (this.value = '')" onblur="(this.value == '') && (this.value = 'Type here to search...')" placeholder="Type here to search..." /></form></li></ul></li></ul></nav>	</div>
# </div></header>
#
# <div id="main-wrapper">
#
#
#
#
#
#
#
# <div id="content" class="container site-content">
#
#
# 	<div id="primary" class="vce-main-content">
#
# 		<div class="main-box">
#
#
# 	<div class="main-box-head">
# 		<h1 class="main-box-title">Category - 心靈雞湯</h1>
# 			</div>
#
# 			<div class="main-box-inside">
#
#
#
#
#
# 					<div class="vce-loop-wrap" >
# 						<article class="vce-post vce-lay-b post-27902 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
#
#  		 	<div class="meta-image">
# 			<a href="http://www.coffeearticle.com/archives/27902" title="成熟的人，看誰都順眼！">
# 				<img width="375" height="195" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-13-375x195.jpg" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-13-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-13-150x79.jpg 150w" sizes="(max-width: 375px) 100vw, 375px" />							</a>
# 		</div>
#
#
# 	<header class="entry-header">
# 					<span class="meta-category"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af" class="category-16">心靈雞湯</a></span>
# 				<h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27902" title="成熟的人，看誰都順眼！">成熟的人，看誰都順眼！</a></h2>
# 		<div class="entry-meta"><div class="meta-item date"><span class="updated">2 天 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27902#respond">Add Comment</a></div></div>	</header>
#
#
# </article>
#
#
#
#
# 						<article class="vce-post vce-lay-b post-27730 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
#
#  		 	<div class="meta-image">
# 			<a href="http://www.coffeearticle.com/archives/27730" title="最痛的結局，就是人走了，感情還在">
# 				<img width="375" height="195" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-3-375x195.jpg" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-3-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-3-150x79.jpg 150w" sizes="(max-width: 375px) 100vw, 375px" />							</a>
# 		</div>
#
#
# 	<header class="entry-header">
# 					<span class="meta-category"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af" class="category-16">心靈雞湯</a></span>
# 				<h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27730" title="最痛的結局，就是人走了，感情還在">最痛的結局，就是人走了，感情還在</a></h2>
# 		<div class="entry-meta"><div class="meta-item date"><span class="updated">1 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27730#respond">Add Comment</a></div></div>	</header>
#
#
# </article>
#
#
#
#
# 						<article class="vce-post vce-lay-b post-27725 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
#
#  		 	<div class="meta-image">
# 			<a href="http://www.coffeearticle.com/archives/27725" title="一輩子不容易，惟有擁有這10種心態，才能活得簡單快樂">
# 				<img width="375" height="195" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-7-375x195.jpg" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-7-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-7-150x79.jpg 150w" sizes="(max-width: 375px) 100vw, 375px" />							</a>
# 		</div>
#
#
# 	<header class="entry-header">
# 					<span class="meta-category"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af" class="category-16">心靈雞湯</a></span>
# 				<h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27725" title="一輩子不容易，惟有擁有這10種心態，才能活得簡單快樂">一輩子不容易，惟有擁有這10種心態，才能活得簡單快樂</a></h2>
# 		<div class="entry-meta"><div class="meta-item date"><span class="updated">1 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27725#respond">Add Comment</a></div></div>	</header>
#
#
# </article>
#
#
#
#
# 						<article class="vce-post vce-lay-b post-27687 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
#
#  		 	<div class="meta-image">
# 			<a href="http://www.coffeearticle.com/archives/27687" title="寫給漸漸老去的自己">
# 				<img width="375" height="195" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-375x195.jpg" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-150x79.jpg 150w" sizes="(max-width: 375px) 100vw, 375px" />							</a>
# 		</div>
#
#
# 	<header class="entry-header">
# 					<span class="meta-category"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af" class="category-16">心靈雞湯</a></span>
# 				<h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27687" title="寫給漸漸老去的自己">寫給漸漸老去的自己</a></h2>
# 		<div class="entry-meta"><div class="meta-item date"><span class="updated">1 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27687#respond">Add Comment</a></div></div>	</header>
#
#
# </article>
# 							<div class="vce-ad-between-posts vce-ad-container"><script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 回應式廣告 -->
# <ins class="adsbygoogle" style="display: block;" data-ad-client="ca-pub-9001105210796177" data-ad-slot="2823355840" data-ad-format="auto"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script></div>
#
#
#
#
# 						<article class="vce-post vce-lay-b post-27599 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
#
#  		 	<div class="meta-image">
# 			<a href="http://www.coffeearticle.com/archives/27599" title="懂事的人最委屈，一定要看看的">
# 				<img width="375" height="195" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-375x195.jpg" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-150x79.jpg 150w" sizes="(max-width: 375px) 100vw, 375px" />							</a>
# 		</div>
#
#
# 	<header class="entry-header">
# 					<span class="meta-category"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af" class="category-16">心靈雞湯</a></span>
# 				<h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27599" title="懂事的人最委屈，一定要看看的">懂事的人最委屈，一定要看看的</a></h2>
# 		<div class="entry-meta"><div class="meta-item date"><span class="updated">2 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27599#respond">Add Comment</a></div></div>	</header>
#
#
# </article>
#
#
#
#
# 						<article class="vce-post vce-lay-b post-27570 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
#
#  		 	<div class="meta-image">
# 			<a href="http://www.coffeearticle.com/archives/27570" title="低調做人，你的路會越走越穩健">
# 				<img width="375" height="195" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-02-4-375x195.jpg" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-02-4-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-02-4-150x79.jpg 150w" sizes="(max-width: 375px) 100vw, 375px" />							</a>
# 		</div>
#
#
# 	<header class="entry-header">
# 					<span class="meta-category"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af" class="category-16">心靈雞湯</a></span>
# 				<h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27570" title="低調做人，你的路會越走越穩健">低調做人，你的路會越走越穩健</a></h2>
# 		<div class="entry-meta"><div class="meta-item date"><span class="updated">2 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27570#respond">Add Comment</a></div></div>	</header>
#
#
# </article>
#
#
#
#
# 						<article class="vce-post vce-lay-b post-27554 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
#
#  		 	<div class="meta-image">
# 			<a href="http://www.coffeearticle.com/archives/27554" title="一輩子真的好難&#8230;.">
# 				<img width="375" height="195" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-04-30-375x195.jpg" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-04-30-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-04-30-150x79.jpg 150w" sizes="(max-width: 375px) 100vw, 375px" />							</a>
# 		</div>
#
#
# 	<header class="entry-header">
# 					<span class="meta-category"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af" class="category-16">心靈雞湯</a></span>
# 				<h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27554" title="一輩子真的好難&#8230;.">一輩子真的好難&#8230;.</a></h2>
# 		<div class="entry-meta"><div class="meta-item date"><span class="updated">2 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27554#respond">Add Comment</a></div></div>	</header>
#
#
# </article>
#
#
#
#
# 						<article class="vce-post vce-lay-b post-27483 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
#
#  		 	<div class="meta-image">
# 			<a href="http://www.coffeearticle.com/archives/27483" title="你越覺得你好運，你就越容易吸引到對的人">
# 				<img width="375" height="195" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-84-375x195.jpg" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-84-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-84-150x79.jpg 150w" sizes="(max-width: 375px) 100vw, 375px" />							</a>
# 		</div>
#
#
# 	<header class="entry-header">
# 					<span class="meta-category"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af" class="category-16">心靈雞湯</a></span>
# 				<h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27483" title="你越覺得你好運，你就越容易吸引到對的人">你越覺得你好運，你就越容易吸引到對的人</a></h2>
# 		<div class="entry-meta"><div class="meta-item date"><span class="updated">2 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27483#respond">Add Comment</a></div></div>	</header>
#
#
# </article>
#
#
#
#
# 						<article class="vce-post vce-lay-b post-27475 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
#
#  		 	<div class="meta-image">
# 			<a href="http://www.coffeearticle.com/archives/27475" title="懂得感恩，才有一切">
# 				<img width="375" height="195" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-83-375x195.jpg" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-83-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-83-150x79.jpg 150w" sizes="(max-width: 375px) 100vw, 375px" />							</a>
# 		</div>
#
#
# 	<header class="entry-header">
# 					<span class="meta-category"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af" class="category-16">心靈雞湯</a></span>
# 				<h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27475" title="懂得感恩，才有一切">懂得感恩，才有一切</a></h2>
# 		<div class="entry-meta"><div class="meta-item date"><span class="updated">2 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27475#respond">Add Comment</a></div></div>	</header>
#
#
# </article>
#
#
#
#
# 						<article class="vce-post vce-lay-b post-27469 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
#
#  		 	<div class="meta-image">
# 			<a href="http://www.coffeearticle.com/archives/27469" title="從前的我，現在的我（讀到心酸）">
# 				<img width="375" height="195" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-82-375x195.jpg" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-82-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-82-150x79.jpg 150w" sizes="(max-width: 375px) 100vw, 375px" />							</a>
# 		</div>
#
#
# 	<header class="entry-header">
# 					<span class="meta-category"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af" class="category-16">心靈雞湯</a></span>
# 				<h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27469" title="從前的我，現在的我（讀到心酸）">從前的我，現在的我（讀到心酸）</a></h2>
# 		<div class="entry-meta"><div class="meta-item date"><span class="updated">2 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27469#respond">Add Comment</a></div></div>	</header>
#
#
# </article>
#
# 													</div>
#
#
# 					<nav id="vce-pagination" class="vce-load-more">
# 		<a href="http://www.coffeearticle.com/archives/category/%E5%BF%83%E9%9D%88%E9%9B%9E%E6%B9%AF/page/2" > Load more</a>	</nav>
#
#
# 			</div>
#
# 		</div>
#
# 	</div>
#
# 		<aside id="sidebar" class="sidebar right">
# 		<div id="custom_html-10" class="widget_text widget widget_custom_html"><h4 class="widget-title">粉絲專頁</h4><div class="textwidget custom-html-widget"><iframe src="https://www.facebook.com/plugins/page.php?href=https%3A%2F%2Fwww.facebook.com%2Fcoffeearticle%2F&tabs&width=340&height=213&small_header=false&adapt_container_width=true&hide_cover=false&show_facepile=true&appId=247236052366034" width="280" height="215" style="border:none;overflow:hidden" scrolling="no" frameborder="0" allowtransparency="true"></iframe></div></div><div id="categories-6" class="widget widget_categories"><h4 class="widget-title">Categories</h4>		<ul>
# 	<li class="cat-item cat-item-7"><a href="http://www.coffeearticle.com/archives/category/cafe%e5%81%a5%e5%ba%b7" ><span class="category-text">健康養生</span><span class="count"><span class="count-hidden">31</span></span></a>
# </li>
# 	<li class="cat-item cat-item-17"><a href="http://www.coffeearticle.com/archives/category/%e5%84%aa%e8%b3%aa%e6%9b%b8%e7%b1%8d" ><span class="category-text">優質書籍</span><span class="count"><span class="count-hidden">1</span></span></a>
# </li>
# 	<li class="cat-item cat-item-4"><a href="http://www.coffeearticle.com/archives/category/cafe%e8%8b%a6%e6%be%80" ><span class="category-text">勵志感人</span><span class="count"><span class="count-hidden">1,281</span></span></a>
# </li>
# 	<li class="cat-item cat-item-56"><a href="http://www.coffeearticle.com/archives/category/%e5%a5%b3%e4%ba%ba%e5%bf%83%e8%aa%9e" ><span class="category-text">女人心語</span><span class="count"><span class="count-hidden">46</span></span></a>
# </li>
# 	<li class="cat-item cat-item-5"><a href="http://www.coffeearticle.com/archives/category/cafe%e7%94%9f%e6%b4%bb" ><span class="category-text">婚姻家庭</span><span class="count"><span class="count-hidden">363</span></span></a>
# </li>
# 	<li class="cat-item cat-item-8"><a href="http://www.coffeearticle.com/archives/category/cafe%e5%af%b5%e7%89%a9" ><span class="category-text">寵物知識</span><span class="count"><span class="count-hidden">10</span></span></a>
# </li>
# 	<li class="cat-item cat-item-16 current-cat"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af" ><span class="category-text">心靈雞湯</span><span class="count"><span class="count-hidden">89</span></span></a>
# </li>
# 	<li class="cat-item cat-item-13"><a href="http://www.coffeearticle.com/archives/category/cafe%e6%84%9f%e6%83%85" ><span class="category-text">愛情故事</span><span class="count"><span class="count-hidden">1,066</span></span></a>
# </li>
# 	<li class="cat-item cat-item-6"><a href="http://www.coffeearticle.com/archives/category/cafe%e9%81%8b%e5%8b%a2" ><span class="category-text">星座運勢</span><span class="count"><span class="count-hidden">532</span></span></a>
# </li>
# 	<li class="cat-item cat-item-15"><a href="http://www.coffeearticle.com/archives/category/%e7%94%9f%e6%b4%bb%e7%99%be%e7%a7%91" ><span class="category-text">生活百科</span><span class="count"><span class="count-hidden">3</span></span></a>
# </li>
# 	<li class="cat-item cat-item-12"><a href="http://www.coffeearticle.com/archives/category/cafe%e8%81%b7%e5%a0%b4" ><span class="category-text">職場人生</span><span class="count"><span class="count-hidden">329</span></span></a>
# </li>
# 	<li class="cat-item cat-item-14"><a href="http://www.coffeearticle.com/archives/category/%e8%b6%a3%e5%91%b3%e6%b8%ac%e9%a9%97" ><span class="category-text">趣味測驗</span><span class="count"><span class="count-hidden">282</span></span></a>
# </li>
# 		</ul>
# </div><div class="vce-sticky"><div id="custom_html-9" class="widget_text widget widget_custom_html"><h4 class="widget-title">贊助商</h4><div class="textwidget custom-html-widget"><script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 回應式廣告 -->
# <ins class="adsbygoogle"
#      style="display:block"
#      data-ad-client="ca-pub-9001105210796177"
#      data-ad-slot="2823355840"
#      data-ad-format="auto"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script></div></div><div id="text-27" class="widget widget_text"><h4 class="widget-title">贊助商</h4>			<div class="textwidget"><p><script type="text/javascript" src="//js1.bloggerads.net/ShowAds.aspx?blogid=20170326000008" async></script></p>
# </div>
# 		</div></div>	</aside>
#
# </div>
#
#
#
# 	<footer id="footer" class="site-footer">
#
# 				<div class="container">
# 			<div class="container-fix">
# 										<div class="bit-3">
# 					<div id="custom_html-8" class="widget_text widget widget_custom_html"><h4 class="widget-title">思想家 粉絲專頁</h4><div class="textwidget custom-html-widget"><iframe src="https://www.facebook.com/plugins/page.php?href=https%3A%2F%2Fwww.facebook.com%2FthoughtVK%2F&tabs&width=340&height=213&small_header=false&adapt_container_width=true&hide_cover=false&show_facepile=true&appId=247236052366034" width="340" height="213" style="border:none;overflow:hidden" scrolling="no" frameborder="0" allowtransparency="true"></iframe></div></div><div id="custom_html-11" class="widget_text widget widget_custom_html"><h4 class="widget-title">在沒有你的世界 粉絲專頁</h4><div class="textwidget custom-html-widget"><iframe src="https://www.facebook.com/plugins/page.php?href=https%3A%2F%2Fwww.facebook.com%2FWithoutYourWorld%2F&tabs&width=340&height=213&small_header=false&adapt_container_width=true&hide_cover=false&show_facepile=true&appId=247236052366034" width="313" height="213" style="border:none;overflow:hidden" scrolling="no" frameborder="0" allowtransparency="true"></iframe></div></div>				</div>
# 							<div class="bit-3">
# 					<div id="vce_posts_widget-11" class="widget vce_posts_widget"><h4 class="widget-title">熱門文章</h4>
#
# 		<ul class="vce-post-list" data-autoplay="">
#
#
# 		 		<li>
#
# 		 			<a href="http://www.coffeearticle.com/archives/27975" class="featured_image_sidebar" title="圖中你認為哪個柿子更軟？測你在其他人眼中好不好欺負！"><span class="vce-post-img"><img width="145" height="100" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-已復原-03-2-145x100.jpg" class="attachment-vce-lay-d size-vce-lay-d wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-已復原-03-2-145x100.jpg 145w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-已復原-03-2-380x260.jpg 380w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-已復原-03-2-634x433.jpg 634w" sizes="(max-width: 145px) 100vw, 145px" /></span></a>
# 		 			<div class="vce-posts-wrap">
# 		 							 			<a href="http://www.coffeearticle.com/archives/27975" title="圖中你認為哪個柿子更軟？測你在其他人眼中好不好欺負！" class="vce-post-link">圖中你認為哪個柿子更軟？測你在其他人眼中好不好欺負！</a>
# 			 					 			</div>
# 		 		</li>
#
# 		 		<li>
#
# 		 			<a href="http://www.coffeearticle.com/archives/27967" class="featured_image_sidebar" title="態度的厚度，決定了你人生的高度！"><span class="vce-post-img"><img width="145" height="100" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-14-145x100.jpg" class="attachment-vce-lay-d size-vce-lay-d wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-14-145x100.jpg 145w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-14-380x260.jpg 380w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-14-634x433.jpg 634w" sizes="(max-width: 145px) 100vw, 145px" /></span></a>
# 		 			<div class="vce-posts-wrap">
# 		 							 			<a href="http://www.coffeearticle.com/archives/27967" title="態度的厚度，決定了你人生的高度！" class="vce-post-link">態度的厚度，決定了你人生的高度！</a>
# 			 					 			</div>
# 		 		</li>
#
# 		 		<li>
#
# 		 			<a href="http://www.coffeearticle.com/archives/27950" class="featured_image_sidebar" title="一輩子太長 找一個能讓你笑的人談戀愛"><span class="vce-post-img"><img width="145" height="100" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-7-145x100.jpg" class="attachment-vce-lay-d size-vce-lay-d wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-7-145x100.jpg 145w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-7-380x260.jpg 380w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-7-634x433.jpg 634w" sizes="(max-width: 145px) 100vw, 145px" /></span></a>
# 		 			<div class="vce-posts-wrap">
# 		 							 			<a href="http://www.coffeearticle.com/archives/27950" title="一輩子太長 找一個能讓你笑的人談戀愛" class="vce-post-link">一輩子太長 找一個能讓你笑的人談戀愛</a>
# 			 					 			</div>
# 		 		</li>
#
# 		 		<li>
#
# 		 			<a href="http://www.coffeearticle.com/archives/27945" class="featured_image_sidebar" title="十二星座男為什麼會弄丟了真愛？"><span class="vce-post-img"><img width="145" height="100" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-05-12-145x100.jpg" class="attachment-vce-lay-d size-vce-lay-d wp-post-image" alt="" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-05-12-145x100.jpg 145w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-05-12-380x260.jpg 380w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-05-12-634x433.jpg 634w" sizes="(max-width: 145px) 100vw, 145px" /></span></a>
# 		 			<div class="vce-posts-wrap">
# 		 							 			<a href="http://www.coffeearticle.com/archives/27945" title="十二星座男為什麼會弄丟了真愛？" class="vce-post-link">十二星座男為什麼會弄丟了真愛？</a>
# 			 					 			</div>
# 		 		</li>
#
# 		  </ul>
#
#
# 		</div>				</div>
# 							<div class="bit-3">
# 					<div id="mks_social_widget-2" class="widget mks_social_widget"><h4 class="widget-title">分享小圖示</h4>
#
# 							<ul class="mks_social_widget_ul">
# 		  			  		<li><a href="https://www.instagram.com/coffeearticle/" title="Instagram" class="instagram_ico soc_rounded" target="_blank" style="width: 47px; height: 47px; font-size: 16px;line-height:52px;"><span>instagram</span></a></li>
# 		  			  		<li><a href="https://www.facebook.com/coffeearticle/" title="Facebook" class="facebook_ico soc_rounded" target="_blank" style="width: 47px; height: 47px; font-size: 16px;line-height:52px;"><span>facebook</span></a></li>
# 		  			  		<li><a href="#" title="Twitter" class="twitter_ico soc_rounded" target="_blank" style="width: 47px; height: 47px; font-size: 16px;line-height:52px;"><span>twitter</span></a></li>
# 		  			  		<li><a href="#" title="Pinterest" class="pinterest_ico soc_rounded" target="_blank" style="width: 47px; height: 47px; font-size: 16px;line-height:52px;"><span>pinterest</span></a></li>
# 		  			  		<li><a href="#" title="RSS" class="rss_ico soc_rounded" target="_blank" style="width: 47px; height: 47px; font-size: 16px;line-height:52px;"><span>rss</span></a></li>
# 		  			  		<li><a href="" title="Paypal" class="paypal_ico soc_rounded" target="_blank" style="width: 47px; height: 47px; font-size: 16px;line-height:52px;"><span>paypal</span></a></li>
# 		  			  </ul>
#
#
# 		</div><div id="text-15" class="widget widget_text"><h4 class="widget-title">授權方式</h4>			<div class="textwidget"><a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-nd/4.0/88x31.png" /></a><br />CoffeeArticle封面由 <a rel="license" href="http://www.coffeearticle.com/">一杯咖啡一篇文章</a> 製作，以<a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/">創用CC 姓名標示-非商業性-禁止改作 4.0 國際授權條款釋出。</a>.</div>
# 		</div>				</div>
# 						</div>
# 		</div>
#
# 					<div class="container-full site-info">
# 				<div class="container">
# 											<div class="vce-wrap-left">
# 							<p>Copyright © 2017 Coffee Article • All Rights Reserved • Theme by Mizmizi</p>						</div>
#
# 											<div class="vce-wrap-right">
# 								<ul id="vce_footer_menu" class="bottom-nav-menu"><li id="menu-item-24474" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-24474"><a href="http://www.coffeearticle.com/contact">Contact</a></li>
# </ul>						</div>
#
#
#
#
# 				</div>
# 			</div>
#
#
# 	</footer>
#
#
# </div>
# </div>
#
# <a href="javascript:void(0)" id="back-top"><i class="fa fa-angle-up"></i></a>
#
# <!-- Popups v1.9.3.2 - https://wordpress.org/plugins/popups/ --><style type="text/css">
# #spu-14959 .spu-close{
# 	font-size: 30px;
# 	color:#666;
# 	text-shadow: 0 1px 0 #fff;
# }
# #spu-14959 .spu-close:hover{
# 	color:#000;
# }
# #spu-14959 {
# 	background-color: #eeeeee;
# 	background-color: rgba(238,238,238,1);
# 	color: #333;
# 	padding: 25px;
# 		border-radius: 0px;
# 	-moz-border-radius: 0px;
# 	-webkit-border-radius: 0px;
# 	-moz-box-shadow:  0px 0px 10px 1px #666;
# 	-webkit-box-shadow:  0px 0px 10px 1px #666;
# 	box-shadow:  0px 0px 10px 1px #666;
# 	width: 400px;
#
# }
# #spu-bg-14959 {
# 	opacity: 0.5;
# 	background-color: #000;
# }
# /*
# * Add custom CSS for this popup
# * Be sure to start your rules with #spu-14959 { } and use !important when needed to override plugin rules
# */</style>
# <div class="spu-bg" id="spu-bg-14959"></div>
# <div class="spu-box  spu-centered spu-total- " id="spu-14959"
#  data-box-id="14959" data-trigger="percentage"
#  data-trigger-number="50"
#  data-spuanimation="fade" data-dconvert-cookie="999" data-dclose-cookie="40" data-nconvert-cookie="spu_conversion_14959" data-nclose-cookie="spu_closing_14959" data-test-mode="0"
#  data-auto-hide="0" data-close-on-conversion="1" data-bgopa="0.5" data-total=""
#  style="left:-99999px !important;right:auto;" data-width="400" >
# 	<div class="spu-content"><p style="text-align: center;"><span style="color: #000000; font-size: 16pt;"><strong><span style="vertical-align: inherit;"><span style="vertical-align: inherit;"><span style="vertical-align: inherit;"><span style="vertical-align: inherit;"><span style="vertical-align: inherit;"><span style="vertical-align: inherit;"><span style="vertical-align: inherit;"><span style="vertical-align: inherit;">想要知道更多文章? !</span></span></span></span></span></span></span></span></strong></span></p>
# <p style="text-align: center;"><span style="color: #000000; font-size: 16pt;"><strong>趕快按個讚，加入我們的專頁吧!</strong></span></p>
# <p><iframe style="border: none; overflow: hidden;" src="https://www.facebook.com/plugins/page.php?href=https%3A%2F%2Fwww.facebook.com%2Fcoffeearticle%2F&amp;tabs&amp;width=340&amp;height=213&amp;small_header=false&amp;adapt_container_width=true&amp;hide_cover=false&amp;show_facepile=true&amp;appId=247236052366034" width="340" height="213" frameborder="0" scrolling="no"></iframe></p>
# </div>
# 	<span class="spu-close spu-close-popup top_right"><i class="spu-icon spu-icon-close"></i></span>
# 	<span class="spu-timer"></span>
# 	</div>
# <!-- / Popups Box -->
# <div id="fb-root" class=" fb_reset"></div><script>
# 		var advanced_ads_ga_UID = false;
# 		var advanced_ads_ga_anonymIP = true;
# advanced_ads_check_adblocker=function(t){function e(t){(window.requestAnimationFrame||window.mozRequestAnimationFrame||window.webkitRequestAnimationFrame||function(t){return setTimeout(t,16)}).call(window,t)}var n=[],a=null;return e(function(){var t=document.createElement("div");t.innerHTML="&nbsp;",t.setAttribute("class","ad_unit ad-unit text-ad text_ad pub_300x250"),t.setAttribute("style","width: 1px !important; height: 1px !important; position: absolute !important; left: 0px !important; top: 0px !important; overflow: hidden !important;"),document.body.appendChild(t),e(function(){var e=window.getComputedStyle&&window.getComputedStyle(t),o=e&&e.getPropertyValue("-moz-binding");a=e&&"none"===e.getPropertyValue("display")||"string"==typeof o&&-1!==o.indexOf("about:");for(var i=0;i<n.length;i++)n[i](a);n=[]})}),function(t){if(null===a)return void n.push(t);t(a)}}(),function(){var t=function(t,e){this.name=t,this.UID=e,this.analyticsObject=null;var n=this,a={hitType:"event",eventCategory:"Advanced Ads",eventAction:"AdBlock",eventLabel:"Yes",nonInteraction:!0,transport:"beacon"};this.analyticsObject="string"==typeof GoogleAnalyticsObject&&"function"==typeof window[GoogleAnalyticsObject]&&window[GoogleAnalyticsObject],!1===this.analyticsObject?(!function(t,e,n,a,o,i,d){t.GoogleAnalyticsObject=o,t[o]=t[o]||function(){(t[o].q=t[o].q||[]).push(arguments)},t[o].l=1*new Date,i=e.createElement(n),d=e.getElementsByTagName(n)[0],i.async=1,i.src="https://www.google-analytics.com/analytics.js",d.parentNode.insertBefore(i,d)}(window,document,"script",0,"_advads_ga"),_advads_ga("create",n.UID,"auto",this.name),advanced_ads_ga_anonymIP&&_advads_ga("set","anonymizeIp",!0),_advads_ga(n.name+".send",a)):(window.console&&window.console.log("Advanced Ads Analytics >> using other's variable named `"+GoogleAnalyticsObject+"`"),window[GoogleAnalyticsObject]("create",n.UID,"auto",this.name),window[GoogleAnalyticsObject]("set","anonymizeIp",!0),window[GoogleAnalyticsObject](n.name+".send",a))};advanced_ads_check_adblocker(function(e){e&&"string"==typeof advanced_ads_ga_UID&&advanced_ads_ga_UID&&new t("advadsTracker",advanced_ads_ga_UID)})}();
# 		</script><script type="text/javascript">
# disableSelection(document.body)
# </script>
# <noscript><img height='1' width='1' style='display: none;' src='https://www.facebook.com/tr?id=369878790102412&ev=PageView&noscript=1&cd[domain]=www.coffeearticle.com' alt='facebook_pixel'></noscript><noscript><img height='1' width='1' style='display: none;' src='https://www.facebook.com/tr?id=369878790102412&ev=造訪網站5以上&noscript=1&cd[post_type]=category&cd[content_name]=%E5%BF%83%E9%9D%88%E9%9B%9E%E6%B9%AF&cd[post_id]=16&cd[domain]=www.coffeearticle.com' alt='facebook_pixel'></noscript>
# 		<script type="text/javascript">
# 		/* <![CDATA[ */
# 		var pys_edd_ajax_events = [];
# 		/* ]]> */
# 		</script>
#
# 		<script type='text/javascript'>
# /* <![CDATA[ */
# var spuvar = {"is_admin":"","disable_style":"","ajax_mode":"","ajax_url":"http:\/\/www.coffeearticle.com\/wp-admin\/admin-ajax.php","ajax_mode_url":"http:\/\/www.coffeearticle.com\/?spu_action=spu_load&lang=","pid":"16","is_front_page":"","is_category":"1","site_url":"http:\/\/www.coffeearticle.com","is_archive":"1","is_search":"","is_preview":"","seconds_confirmation_close":"5"};
# var spuvar_social = [];
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://www.coffeearticle.com/wp-content/plugins/popups/public/assets/js/public.js?ver=1.9.3.2'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var vce_js_settings = {"sticky_header":"1","sticky_header_offset":"700","sticky_header_logo":"","logo":"http:\/\/www.coffeearticle.com\/wp-content\/uploads\/2018\/06\/\u672a\u547d\u540d-1-01.png","logo_retina":"","logo_mobile":"","logo_mobile_retina":"","rtl_mode":"0","ajax_url":"http:\/\/www.coffeearticle.com\/wp-admin\/admin-ajax.php","ajax_mega_menu":"1","mega_menu_slider":"","mega_menu_subcats":"","lay_fa_grid_center":"","full_slider_autoplay":"","grid_slider_autoplay":"","grid_big_slider_autoplay":"","fa_big_opacity":{"1":"0.5","2":"0.7"},"top_bar_mobile":"1","top_bar_mobile_group":"","top_bar_more_link":"More"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://www.coffeearticle.com/wp-content/themes/voice/js/min.js?ver=2.7'></script>
# <script type='text/javascript' src='http://www.coffeearticle.com/wp-includes/js/wp-embed.min.js?ver=4.9.8'></script>
#
# </body>
# </html>
# <!-- Dynamic page generated in 1.830 seconds. -->
# <!-- Cached page generated by WP-Super-Cache on 2018-09-13 06:27:04 -->
#
# <!-- Compression = gzip -->

# %%
import requests
from bs4 import BeautifulSoup as BS4
html = 'http://www.coffeearticle.com/archives/category/心靈雞湯'
headers = {'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1"}
re = requests.get(html, headers = headers)
soup = BS4(re.text)
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]><html class="ie8"><![endif]--><!--[if IE 9]><html class="ie9"><![endif]--><!--[if gt IE 8]><!--><html lang="zh-TW" xmlns:fb="http://ogp.me/ns/fb#" xmlns:og="http://ogp.me/ns#"> <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="user-scalable=yes, width=device-width, initial-scale=1.0, maximum-scale=1, minimum-scale=1" name="viewport"/>
# <!--[if lt IE 9]>
# 	<script src="http://www.coffeearticle.com/wp-content/themes/voice/js/html5.js"></script>
# <![endif]-->
# <title>心靈雞湯 – 一杯咖啡一篇文章</title>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="http://www.coffeearticle.com/feed" rel="alternate" title="訂閱 一杯咖啡一篇文章 »" type="application/rss+xml"/>
# <link href="http://www.coffeearticle.com/comments/feed" rel="alternate" title="訂閱 一杯咖啡一篇文章 » 迴響" type="application/rss+xml"/>
# <link href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af/feed" rel="alternate" title="訂閱 一杯咖啡一篇文章 » 心靈雞湯 分類" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/www.coffeearticle.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.9.8"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <!-- managing ads with Advanced Ads – https://wpadvancedads.com/ --><script>
# 					advanced_ads_ready=function(){var fns=[],listener,doc=typeof document==="object"&&document,hack=doc&&doc.documentElement.doScroll,domContentLoaded="DOMContentLoaded",loaded=doc&&(hack?/^loaded|^c/:/^loaded|^i|^c/).test(doc.readyState);if(!loaded&&doc){listener=function(){doc.removeEventListener(domContentLoaded,listener);window.removeEventListener("load",listener);loaded=1;while(listener=fns.shift())listener()};doc.addEventListener(domContentLoaded,listener);window.addEventListener("load",listener)}return function(fn){loaded?setTimeout(fn,0):fns.push(fn)}}();
# 			</script><style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="http://www.coffeearticle.com/wp-content/plugins/meks-flexible-shortcodes/css/simple-line/simple-line-icons.css?ver=1.3.1" id="mks_shortcodes_simple_line_icons-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="http://www.coffeearticle.com/wp-content/plugins/meks-flexible-shortcodes/css/style.css?ver=1.3.1" id="mks_shortcodes_css-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="http://www.coffeearticle.com/wp-content/plugins/popups/public/assets/css/public.css?ver=1.9.3.2" id="spu-public-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://fonts.googleapis.com/css?family=Open+Sans%3A400&amp;subset=latin%2Clatin-ext&amp;ver=2.7" id="vce_font_0-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="http://fonts.googleapis.com/css?family=Roboto+Slab%3A400&amp;subset=latin%2Clatin-ext&amp;ver=2.7" id="vce_font_1-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="http://www.coffeearticle.com/wp-content/themes/voice/css/min.css?ver=2.7" id="vce_style-css" media="screen, print" rel="stylesheet" type="text/css"/>
# <style id="vce_style-inline-css" type="text/css">
# body, button, input, select, textarea{font-size: 2rem;}.vce-single .entry-headline p{font-size: 2.2rem;}.main-navigation a{font-size: rem;}.sidebar .widget-title{font-size: 2rem;}.sidebar .widget{font-size: 1.5rem;}.vce-featured-link-article{font-size: 5rem;}.vce-featured-grid-big.vce-featured-grid .vce-featured-link-article{font-size: 3.4rem;}.vce-featured-grid .vce-featured-link-article{font-size: 2.2rem;}h1 { font-size: 4.3rem; }h2 { font-size: 4rem; }h3 { font-size: 3.5rem; }h4 { font-size: 2.5rem; }h5 { font-size: 2rem; }h6 { font-size: 1.8rem; }.comment-reply-title, .main-box-title{font-size: 2.2rem;}h1.entry-title{font-size: 4.3rem;}.vce-lay-a .entry-title a{font-size: 3.4rem;}.vce-lay-b .entry-title{font-size: 2.4rem;}.vce-lay-c .entry-title, .vce-sid-none .vce-lay-c .entry-title{font-size: 2.2rem;}.vce-lay-d .entry-title{font-size: 1.5rem;}.vce-lay-e .entry-title{font-size: 1.4rem;}.vce-lay-f .entry-title{font-size: 1.4rem;}.vce-lay-g .entry-title a, .vce-lay-g .entry-title a:hover{font-size: 3rem;}.vce-lay-h .entry-title{font-size: 2.4rem;}.entry-meta div,.entry-meta div a,.vce-lay-g .meta-item,.vce-lay-c .meta-item{font-size: 1.5rem;}.vce-lay-d .meta-category a,.vce-lay-d .entry-meta div,.vce-lay-d .entry-meta div a,.vce-lay-e .entry-meta div,.vce-lay-e .entry-meta div a,.vce-lay-e .fn,.vce-lay-e .meta-item{font-size: 1.5rem;}body {background-color:#f0f0f0;}body,.mks_author_widget h3,.site-description,.meta-category a,textarea {font-family: 'Open Sans';font-weight: 400;}h1,h2,h3,h4,h5,h6,blockquote,.vce-post-link,.site-title,.site-title a,.main-box-title,.comment-reply-title,.entry-title a,.vce-single .entry-headline p,.vce-prev-next-link,.author-title,.mks_pullquote,.widget_rss ul li .rsswidget,#bbpress-forums .bbp-forum-title,#bbpress-forums .bbp-topic-permalink {font-family: 'Comic Sans MS', cursive;font-weight: 400;}.main-navigation a,.sidr a{font-family: 'Roboto Slab';font-weight: 400;}.vce-single .entry-content,.vce-single .entry-headline,.vce-single .entry-footer{width: 600px;}.vce-lay-a .lay-a-content{width: 600px;max-width: 600px;}.vce-page .entry-content,.vce-page .entry-title-page {width: 600px;}.vce-sid-none .vce-single .entry-content,.vce-sid-none .vce-single .entry-headline,.vce-sid-none .vce-single .entry-footer {width: 600px;}.vce-sid-none .vce-page .entry-content,.vce-sid-none .vce-page .entry-title-page,.error404 .entry-content {width: 600px;max-width: 600px;}body, button, input, select, textarea{color: #444444;}h1,h2,h3,h4,h5,h6,.entry-title a,.prev-next-nav a,#bbpress-forums .bbp-forum-title, #bbpress-forums .bbp-topic-permalink,.woocommerce ul.products li.product .price .amount{color: #232323;}a,.entry-title a:hover,.vce-prev-next-link:hover,.vce-author-links a:hover,.required,.error404 h4,.prev-next-nav a:hover,#bbpress-forums .bbp-forum-title:hover, #bbpress-forums .bbp-topic-permalink:hover,.woocommerce ul.products li.product h3:hover,.woocommerce ul.products li.product h3:hover mark,.main-box-title a:hover{color: #cf4d35;}.vce-square,.vce-main-content .mejs-controls .mejs-time-rail .mejs-time-current,button,input[type="button"],input[type="reset"],input[type="submit"],.vce-button,.pagination-wapper a,#vce-pagination .next.page-numbers,#vce-pagination .prev.page-numbers,#vce-pagination .page-numbers,#vce-pagination .page-numbers.current,.vce-link-pages a,#vce-pagination a,.vce-load-more a,.vce-slider-pagination .owl-nav > div,.vce-mega-menu-posts-wrap .owl-nav > div,.comment-reply-link:hover,.vce-featured-section a,.vce-lay-g .vce-featured-info .meta-category a,.vce-404-menu a,.vce-post.sticky .meta-image:before,#vce-pagination .page-numbers:hover,#bbpress-forums .bbp-pagination .current,#bbpress-forums .bbp-pagination a:hover,.woocommerce #respond input#submit,.woocommerce a.button,.woocommerce button.button,.woocommerce input.button,.woocommerce ul.products li.product .added_to_cart,.woocommerce #respond input#submit:hover,.woocommerce a.button:hover,.woocommerce button.button:hover,.woocom ...
# </style>
# <link href="http://www.coffeearticle.com/wp-content/plugins/meks-easy-ads-widget/css/style.css?ver=2.0.4" id="meks-ads-widget-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.coffeearticle.com/wp-content/plugins/meks-simple-flickr-widget/css/style.css?ver=1.1.3" id="meks-flickr-widget-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.coffeearticle.com/wp-content/plugins/meks-smart-social-widget/css/style.css?ver=1.3.5" id="meks-social-widget-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.coffeearticle.com/wp-content/plugins/meks-themeforest-smart-widget/css/style.css?ver=1.2" id="meks-themeforest-widget-css" media="all" rel="stylesheet" type="text/css"/>
# <script src="http://www.coffeearticle.com/wp-includes/js/jquery/jquery.js?ver=1.12.4" type="text/javascript"></script>
# <script src="http://www.coffeearticle.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript"></script>
# <script src="http://www.coffeearticle.com/wp-content/plugins/meks-flexible-shortcodes/js/main.js?ver=1.3.1" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var pys_fb_pixel_options = {"woo":{"addtocart_enabled":false,"product_data":""},"gdpr":{"disable":false,"enable_before_consent":"1","ginger_enabled":false,"cookiebot_enabled":false}};
# var pys_events = [{"type":"init","name":"369878790102412","params":[]},{"type":"track","name":"PageView","params":{"domain":"www.coffeearticle.com"},"delay":0},{"type":"trackCustom","name":"\u9020\u8a2a\u7db2\u7ad95\u4ee5\u4e0a","params":{"post_type":"category","content_name":"\u5fc3\u9748\u96de\u6e6f","post_id":16,"domain":"www.coffeearticle.com"},"delay":5}];
# /* ]]> */
# </script>
# <script src="http://www.coffeearticle.com/wp-content/plugins/pixelyoursite/js/public.js?ver=5.3.2" type="text/javascript"></script>
# <link href="http://www.coffeearticle.com/wp-json/" rel="https://api.w.org/"/>
# <link href="http://www.coffeearticle.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="http://www.coffeearticle.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 4.9.8" name="generator"/>
# <meta content="1441185349481496" property="fb:pages"/>
# <meta content="http://www.coffeearticle.com/archives/27902?ia_markup=1" property="ia:markup_url"/>
# <script type="text/javascript">
# <!--
# /******************************************************************************
# ***   COPY PROTECTED BY http://chetangole.com/blog/wp-copyprotect/   version 3.1.0 ****
# ******************************************************************************/
# function clickIE4(){
# if (event.button==2){
# return false;
# }
# }
# function clickNS4(e){
# if (document.layers||document.getElementById&&!document.all){
# if (e.which==2||e.which==3){
# return false;
# }
# }
# }
#
# if (document.layers){
# document.captureEvents(Event.MOUSEDOWN);
# document.onmousedown=clickNS4;
# }
# else if (document.all&&!document.getElementById){
# document.onmousedown=clickIE4;
# }
#
# document.oncontextmenu=new Function("return false")
# // -->
# </script>
# <script type="text/javascript">
# /******************************************************************************
# ***   COPY PROTECTED BY http://chetangole.com/blog/wp-copyprotect/   version 3.1.0 ****
# ******************************************************************************/
# function disableSelection(target){
# if (typeof target.onselectstart!="undefined") //For IE
# 	target.onselectstart=function(){return false}
# else if (typeof target.style.MozUserSelect!="undefined") //For Firefox
# 	target.style.MozUserSelect="none"
# else //All other route (For Opera)
# 	target.onmousedown=function(){return false}
# target.style.cursor = "default"
# }
# </script>
# <!-- Facebook Pixel code is added on this page by PixelYourSite FREE v5.3.2 plugin. You can test it with Pixel Helper Chrome Extension. -->
# <link href="http://www.coffeearticle.com/wp-content/uploads/2018/06/favicon-194x194.png" rel="shortcut icon" type="image/x-icon"/> <style id="wp-custom-css" type="text/css">
# 			p {
#     margin-bottom: 20px;
#     word-wrap: break-word;
#     FONT-SIZE: 16px;
# }		</style>
# <!-- START - Open Graph for Facebook, Google+ and Twitter Card Tags 2.2.4.2 -->
# <!-- Facebook Open Graph -->
# <meta content="zh_TW" property="og:locale"/>
# <meta content="一杯咖啡一篇文章" property="og:site_name"/>
# <meta content="心靈雞湯" property="og:title"/>
# <meta content="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="心靈雞湯" property="og:description"/>
# <meta content="https://www.facebook.com/coffeearticle/" property="article:publisher"/>
# <meta content="https://www.facebook.com/weiche.hsu.90" property="fb:admins"/>
# <!-- Google+ / Schema.org -->
# <meta content="心靈雞湯" itemprop="name"/>
# <meta content="心靈雞湯" itemprop="headline"/>
# <meta content="心靈雞湯" itemprop="description"/>
# <!--<meta itemprop="publisher" content="一杯咖啡一篇文章"/>--> <!-- To solve: The attribute publisher.itemtype has an invalid value -->
# <!-- Twitter Cards -->
# <meta content="心靈雞湯" name="twitter:title"/>
# <meta content="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af" name="twitter:url"/>
# <meta content="心靈雞湯" name="twitter:description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <!-- SEO -->
# <!-- Misc. tags -->
# <!-- is_category -->
# <!-- END - Open Graph for Facebook, Google+ and Twitter Card Tags 2.2.4.2 -->
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({
#           google_ad_client: "ca-pub-9001105210796177",
#           enable_page_level_ads: true
#      });
# </script>
# </head>
# <body class="archive category category-16 chrome vce-sid-right">
# <div id="vce-main">
# <header class="main-header" id="header">
# <div class="top-header">
# <div class="container">
# <div class="vce-wrap-left">
# <ul class="top-nav-menu" id="vce_top_navigation_menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-24566" id="menu-item-24566"><a href="http://www.coffeearticle.com/%e9%a6%96%e9%a0%81">首頁</a></li>
# </ul> </div>
# <div class="vce-wrap-right">
# <div class="menu-social-menu-container"><ul class="soc-nav-menu" id="vce_social_menu"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-24385" id="menu-item-24385"><a href="https://www.facebook.com/coffeearticle/"><span class="vce-social-name">Facebook</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-24390" id="menu-item-24390"><a href="https://www.instagram.com/coffeearticle/"><span class="vce-social-name">Instagram</span></a></li>
# </ul></div> </div>
# </div>
# </div><div class="container header-1-wrapper header-main-area">
# <div class="vce-res-nav">
# <a class="vce-responsive-nav" href="#sidr-main"><i class="fa fa-bars"></i></a>
# </div>
# <div class="site-branding">
# <span class="site-title">
# <a class="has-logo" href="http://www.coffeearticle.com/" title="一杯咖啡一篇文章"><img alt="一杯咖啡一篇文章" src="http://www.coffeearticle.com/wp-content/uploads/2018/06/未命名-1-01.png"/></a>
# </span>
# <span class="site-description"></span>
# </div></div>
# <div class="header-bottom-wrapper">
# <div class="container">
# <nav class="main-navigation" id="site-navigation" role="navigation">
# <ul class="nav-menu" id="vce_main_navigation_menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-24436" id="menu-item-24436"><a href="http://www.coffeearticle.com/">首頁</a></li><li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24553 vce-cat-4" id="menu-item-24553"><a href="http://www.coffeearticle.com/archives/category/cafe%e8%8b%a6%e6%be%80">勵志感人</a></li><li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24540 vce-cat-13" id="menu-item-24540"><a href="http://www.coffeearticle.com/archives/category/cafe%e6%84%9f%e6%83%85">愛情故事</a></li><li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24541 vce-cat-6" id="menu-item-24541"><a href="http://www.coffeearticle.com/archives/category/cafe%e9%81%8b%e5%8b%a2">星座運勢</a></li><li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24542 vce-cat-5" id="menu-item-24542"><a href="http://www.coffeearticle.com/archives/category/cafe%e7%94%9f%e6%b4%bb">婚姻家庭</a></li><li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24543 vce-cat-12" id="menu-item-24543"><a href="http://www.coffeearticle.com/archives/category/cafe%e8%81%b7%e5%a0%b4">職場人生</a></li><li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24544 vce-cat-14" id="menu-item-24544"><a href="http://www.coffeearticle.com/archives/category/%e8%b6%a3%e5%91%b3%e6%b8%ac%e9%a9%97">趣味測驗</a></li><li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24545 vce-cat-7" id="menu-item-24545"><a href="http://www.coffeearticle.com/archives/category/cafe%e5%81%a5%e5%ba%b7">健康養生</a></li><li class="menu-item menu-item-type-taxonomy menu-item-object-category current-menu-item menu-item-24546 vce-cat-16" id="menu-item-24546"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af">心靈雞湯</a></li><li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-24547 vce-cat-8" id="menu-item-24547"><a href="http://www.coffeearticle.com/archives/category/cafe%e5%af%b5%e7%89%a9">寵物知識</a></li><li class="search-header-wrap"><a class="search_header" href="javascript:void(0)"><i class="fa fa-search"></i></a><ul class="search-header-form-ul"><li><form action="http://www.coffeearticle.com/" class="search-header-form" method="get">
# <input class="search-input" name="s" onblur="(this.value == '') &amp;&amp; (this.value = 'Type here to search...')" onfocus="(this.value == 'Type here to search...') &amp;&amp; (this.value = '')" placeholder="Type here to search..." size="20" type="text" value="Type here to search..."/></form></li></ul></li></ul></nav> </div>
# </div></header>
# <div id="main-wrapper">
# <div class="container site-content" id="content">
# <div class="vce-main-content" id="primary">
# <div class="main-box">
# <div class="main-box-head">
# <h1 class="main-box-title">Category - 心靈雞湯</h1>
# </div>
# <div class="main-box-inside">
# <div class="vce-loop-wrap">
# <article class="vce-post vce-lay-b post-27902 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
# <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27902" title="成熟的人，看誰都順眼！">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-13-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-13-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-13-150x79.jpg 150w" width="375"/> </a>
# </div>
# <header class="entry-header">
# <span class="meta-category"><a class="category-16" href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af">心靈雞湯</a></span>
# <h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27902" title="成熟的人，看誰都順眼！">成熟的人，看誰都順眼！</a></h2>
# <div class="entry-meta"><div class="meta-item date"><span class="updated">2 天 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27902#respond">Add Comment</a></div></div> </header>
# </article>
# <article class="vce-post vce-lay-b post-27730 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
# <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27730" title="最痛的結局，就是人走了，感情還在">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-3-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-3-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-3-150x79.jpg 150w" width="375"/> </a>
# </div>
# <header class="entry-header">
# <span class="meta-category"><a class="category-16" href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af">心靈雞湯</a></span>
# <h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27730" title="最痛的結局，就是人走了，感情還在">最痛的結局，就是人走了，感情還在</a></h2>
# <div class="entry-meta"><div class="meta-item date"><span class="updated">1 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27730#respond">Add Comment</a></div></div> </header>
# </article>
# <article class="vce-post vce-lay-b post-27725 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
# <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27725" title="一輩子不容易，惟有擁有這10種心態，才能活得簡單快樂">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-7-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-7-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-7-150x79.jpg 150w" width="375"/> </a>
# </div>
# <header class="entry-header">
# <span class="meta-category"><a class="category-16" href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af">心靈雞湯</a></span>
# <h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27725" title="一輩子不容易，惟有擁有這10種心態，才能活得簡單快樂">一輩子不容易，惟有擁有這10種心態，才能活得簡單快樂</a></h2>
# <div class="entry-meta"><div class="meta-item date"><span class="updated">1 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27725#respond">Add Comment</a></div></div> </header>
# </article>
# <article class="vce-post vce-lay-b post-27687 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
# <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27687" title="寫給漸漸老去的自己">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-150x79.jpg 150w" width="375"/> </a>
# </div>
# <header class="entry-header">
# <span class="meta-category"><a class="category-16" href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af">心靈雞湯</a></span>
# <h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27687" title="寫給漸漸老去的自己">寫給漸漸老去的自己</a></h2>
# <div class="entry-meta"><div class="meta-item date"><span class="updated">1 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27687#respond">Add Comment</a></div></div> </header>
# </article>
# <div class="vce-ad-between-posts vce-ad-container"><script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 回應式廣告 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9001105210796177" data-ad-format="auto" data-ad-slot="2823355840" style="display: block;"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script></div>
# <article class="vce-post vce-lay-b post-27599 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
# <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27599" title="懂事的人最委屈，一定要看看的">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-150x79.jpg 150w" width="375"/> </a>
# </div>
# <header class="entry-header">
# <span class="meta-category"><a class="category-16" href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af">心靈雞湯</a></span>
# <h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27599" title="懂事的人最委屈，一定要看看的">懂事的人最委屈，一定要看看的</a></h2>
# <div class="entry-meta"><div class="meta-item date"><span class="updated">2 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27599#respond">Add Comment</a></div></div> </header>
# </article>
# <article class="vce-post vce-lay-b post-27570 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
# <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27570" title="低調做人，你的路會越走越穩健">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-02-4-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-02-4-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-02-4-150x79.jpg 150w" width="375"/> </a>
# </div>
# <header class="entry-header">
# <span class="meta-category"><a class="category-16" href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af">心靈雞湯</a></span>
# <h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27570" title="低調做人，你的路會越走越穩健">低調做人，你的路會越走越穩健</a></h2>
# <div class="entry-meta"><div class="meta-item date"><span class="updated">2 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27570#respond">Add Comment</a></div></div> </header>
# </article>
# <article class="vce-post vce-lay-b post-27554 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
# <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27554" title="一輩子真的好難….">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-04-30-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-04-30-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-04-30-150x79.jpg 150w" width="375"/> </a>
# </div>
# <header class="entry-header">
# <span class="meta-category"><a class="category-16" href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af">心靈雞湯</a></span>
# <h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27554" title="一輩子真的好難….">一輩子真的好難….</a></h2>
# <div class="entry-meta"><div class="meta-item date"><span class="updated">2 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27554#respond">Add Comment</a></div></div> </header>
# </article>
# <article class="vce-post vce-lay-b post-27483 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
# <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27483" title="你越覺得你好運，你就越容易吸引到對的人">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-84-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-84-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-84-150x79.jpg 150w" width="375"/> </a>
# </div>
# <header class="entry-header">
# <span class="meta-category"><a class="category-16" href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af">心靈雞湯</a></span>
# <h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27483" title="你越覺得你好運，你就越容易吸引到對的人">你越覺得你好運，你就越容易吸引到對的人</a></h2>
# <div class="entry-meta"><div class="meta-item date"><span class="updated">2 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27483#respond">Add Comment</a></div></div> </header>
# </article>
# <article class="vce-post vce-lay-b post-27475 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
# <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27475" title="懂得感恩，才有一切">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-83-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-83-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-83-150x79.jpg 150w" width="375"/> </a>
# </div>
# <header class="entry-header">
# <span class="meta-category"><a class="category-16" href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af">心靈雞湯</a></span>
# <h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27475" title="懂得感恩，才有一切">懂得感恩，才有一切</a></h2>
# <div class="entry-meta"><div class="meta-item date"><span class="updated">2 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27475#respond">Add Comment</a></div></div> </header>
# </article>
# <article class="vce-post vce-lay-b post-27469 post type-post status-publish format-standard has-post-thumbnail hentry category-16">
# <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27469" title="從前的我，現在的我（讀到心酸）">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-82-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-82-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-82-150x79.jpg 150w" width="375"/> </a>
# </div>
# <header class="entry-header">
# <span class="meta-category"><a class="category-16" href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af">心靈雞湯</a></span>
# <h2 class="entry-title"><a href="http://www.coffeearticle.com/archives/27469" title="從前的我，現在的我（讀到心酸）">從前的我，現在的我（讀到心酸）</a></h2>
# <div class="entry-meta"><div class="meta-item date"><span class="updated">2 週 ago</span></div><div class="meta-item comments"><a href="http://www.coffeearticle.com/archives/27469#respond">Add Comment</a></div></div> </header>
# </article>
# </div>
# <nav class="vce-load-more" id="vce-pagination">
# <a href="http://www.coffeearticle.com/archives/category/%E5%BF%83%E9%9D%88%E9%9B%9E%E6%B9%AF/page/2"> Load more</a> </nav>
# </div>
# </div>
# </div>
# <aside class="sidebar right" id="sidebar">
# <div class="widget_text widget widget_custom_html" id="custom_html-10"><h4 class="widget-title">粉絲專頁</h4><div class="textwidget custom-html-widget"><iframe allowtransparency="true" frameborder="0" height="215" scrolling="no" src="https://www.facebook.com/plugins/page.php?href=https%3A%2F%2Fwww.facebook.com%2Fcoffeearticle%2F&amp;tabs&amp;width=340&amp;height=213&amp;small_header=false&amp;adapt_container_width=true&amp;hide_cover=false&amp;show_facepile=true&amp;appId=247236052366034" style="border:none;overflow:hidden" width="280"></iframe></div></div><div class="widget widget_categories" id="categories-6"><h4 class="widget-title">Categories</h4> <ul>
# <li class="cat-item cat-item-7"><a href="http://www.coffeearticle.com/archives/category/cafe%e5%81%a5%e5%ba%b7"><span class="category-text">健康養生</span><span class="count"><span class="count-hidden">31</span></span></a>
# </li>
# <li class="cat-item cat-item-17"><a href="http://www.coffeearticle.com/archives/category/%e5%84%aa%e8%b3%aa%e6%9b%b8%e7%b1%8d"><span class="category-text">優質書籍</span><span class="count"><span class="count-hidden">1</span></span></a>
# </li>
# <li class="cat-item cat-item-4"><a href="http://www.coffeearticle.com/archives/category/cafe%e8%8b%a6%e6%be%80"><span class="category-text">勵志感人</span><span class="count"><span class="count-hidden">1,281</span></span></a>
# </li>
# <li class="cat-item cat-item-56"><a href="http://www.coffeearticle.com/archives/category/%e5%a5%b3%e4%ba%ba%e5%bf%83%e8%aa%9e"><span class="category-text">女人心語</span><span class="count"><span class="count-hidden">46</span></span></a>
# </li>
# <li class="cat-item cat-item-5"><a href="http://www.coffeearticle.com/archives/category/cafe%e7%94%9f%e6%b4%bb"><span class="category-text">婚姻家庭</span><span class="count"><span class="count-hidden">363</span></span></a>
# </li>
# <li class="cat-item cat-item-8"><a href="http://www.coffeearticle.com/archives/category/cafe%e5%af%b5%e7%89%a9"><span class="category-text">寵物知識</span><span class="count"><span class="count-hidden">10</span></span></a>
# </li>
# <li class="cat-item cat-item-16 current-cat"><a href="http://www.coffeearticle.com/archives/category/%e5%bf%83%e9%9d%88%e9%9b%9e%e6%b9%af"><span class="category-text">心靈雞湯</span><span class="count"><span class="count-hidden">89</span></span></a>
# </li>
# <li class="cat-item cat-item-13"><a href="http://www.coffeearticle.com/archives/category/cafe%e6%84%9f%e6%83%85"><span class="category-text">愛情故事</span><span class="count"><span class="count-hidden">1,066</span></span></a>
# </li>
# <li class="cat-item cat-item-6"><a href="http://www.coffeearticle.com/archives/category/cafe%e9%81%8b%e5%8b%a2"><span class="category-text">星座運勢</span><span class="count"><span class="count-hidden">532</span></span></a>
# </li>
# <li class="cat-item cat-item-15"><a href="http://www.coffeearticle.com/archives/category/%e7%94%9f%e6%b4%bb%e7%99%be%e7%a7%91"><span class="category-text">生活百科</span><span class="count"><span class="count-hidden">3</span></span></a>
# </li>
# <li class="cat-item cat-item-12"><a href="http://www.coffeearticle.com/archives/category/cafe%e8%81%b7%e5%a0%b4"><span class="category-text">職場人生</span><span class="count"><span class="count-hidden">329</span></span></a>
# </li>
# <li class="cat-item cat-item-14"><a href="http://www.coffeearticle.com/archives/category/%e8%b6%a3%e5%91%b3%e6%b8%ac%e9%a9%97"><span class="category-text">趣味測驗</span><span class="count"><span class="count-hidden">282</span></span></a>
# </li>
# </ul>
# </div><div class="vce-sticky"><div class="widget_text widget widget_custom_html" id="custom_html-9"><h4 class="widget-title">贊助商</h4><div class="textwidget custom-html-widget"><script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 回應式廣告 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9001105210796177" data-ad-format="auto" data-ad-slot="2823355840" style="display:block"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script></div></div><div class="widget widget_text" id="text-27"><h4 class="widget-title">贊助商</h4> <div class="textwidget"><p><script async="" src="//js1.bloggerads.net/ShowAds.aspx?blogid=20170326000008" type="text/javascript"></script></p>
# </div>
# </div></div> </aside>
# </div>
# <footer class="site-footer" id="footer">
# <div class="container">
# <div class="container-fix">
# <div class="bit-3">
# <div class="widget_text widget widget_custom_html" id="custom_html-8"><h4 class="widget-title">思想家 粉絲專頁</h4><div class="textwidget custom-html-widget"><iframe allowtransparency="true" frameborder="0" height="213" scrolling="no" src="https://www.facebook.com/plugins/page.php?href=https%3A%2F%2Fwww.facebook.com%2FthoughtVK%2F&amp;tabs&amp;width=340&amp;height=213&amp;small_header=false&amp;adapt_container_width=true&amp;hide_cover=false&amp;show_facepile=true&amp;appId=247236052366034" style="border:none;overflow:hidden" width="340"></iframe></div></div><div class="widget_text widget widget_custom_html" id="custom_html-11"><h4 class="widget-title">在沒有你的世界 粉絲專頁</h4><div class="textwidget custom-html-widget"><iframe allowtransparency="true" frameborder="0" height="213" scrolling="no" src="https://www.facebook.com/plugins/page.php?href=https%3A%2F%2Fwww.facebook.com%2FWithoutYourWorld%2F&amp;tabs&amp;width=340&amp;height=213&amp;small_header=false&amp;adapt_container_width=true&amp;hide_cover=false&amp;show_facepile=true&amp;appId=247236052366034" style="border:none;overflow:hidden" width="313"></iframe></div></div> </div>
# <div class="bit-3">
# <div class="widget vce_posts_widget" id="vce_posts_widget-11"><h4 class="widget-title">熱門文章</h4>
# <ul class="vce-post-list" data-autoplay="">
# <li>
# <a class="featured_image_sidebar" href="http://www.coffeearticle.com/archives/27975" title="圖中你認為哪個柿子更軟？測你在其他人眼中好不好欺負！"><span class="vce-post-img"><img alt="" class="attachment-vce-lay-d size-vce-lay-d wp-post-image" height="100" sizes="(max-width: 145px) 100vw, 145px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-已復原-03-2-145x100.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-已復原-03-2-145x100.jpg 145w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-已復原-03-2-380x260.jpg 380w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-已復原-03-2-634x433.jpg 634w" width="145"/></span></a>
# <div class="vce-posts-wrap">
# <a class="vce-post-link" href="http://www.coffeearticle.com/archives/27975" title="圖中你認為哪個柿子更軟？測你在其他人眼中好不好欺負！">圖中你認為哪個柿子更軟？測你在其他人眼中好不好欺負！</a>
# </div>
# </li>
# <li>
# <a class="featured_image_sidebar" href="http://www.coffeearticle.com/archives/27967" title="態度的厚度，決定了你人生的高度！"><span class="vce-post-img"><img alt="" class="attachment-vce-lay-d size-vce-lay-d wp-post-image" height="100" sizes="(max-width: 145px) 100vw, 145px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-14-145x100.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-14-145x100.jpg 145w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-14-380x260.jpg 380w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-14-634x433.jpg 634w" width="145"/></span></a>
# <div class="vce-posts-wrap">
# <a class="vce-post-link" href="http://www.coffeearticle.com/archives/27967" title="態度的厚度，決定了你人生的高度！">態度的厚度，決定了你人生的高度！</a>
# </div>
# </li>
# <li>
# <a class="featured_image_sidebar" href="http://www.coffeearticle.com/archives/27950" title="一輩子太長 找一個能讓你笑的人談戀愛"><span class="vce-post-img"><img alt="" class="attachment-vce-lay-d size-vce-lay-d wp-post-image" height="100" sizes="(max-width: 145px) 100vw, 145px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-7-145x100.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-7-145x100.jpg 145w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-7-380x260.jpg 380w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-7-634x433.jpg 634w" width="145"/></span></a>
# <div class="vce-posts-wrap">
# <a class="vce-post-link" href="http://www.coffeearticle.com/archives/27950" title="一輩子太長 找一個能讓你笑的人談戀愛">一輩子太長 找一個能讓你笑的人談戀愛</a>
# </div>
# </li>
# <li>
# <a class="featured_image_sidebar" href="http://www.coffeearticle.com/archives/27945" title="十二星座男為什麼會弄丟了真愛？"><span class="vce-post-img"><img alt="" class="attachment-vce-lay-d size-vce-lay-d wp-post-image" height="100" sizes="(max-width: 145px) 100vw, 145px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-05-12-145x100.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-05-12-145x100.jpg 145w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-05-12-380x260.jpg 380w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-05-12-634x433.jpg 634w" width="145"/></span></a>
# <div class="vce-posts-wrap">
# <a class="vce-post-link" href="http://www.coffeearticle.com/archives/27945" title="十二星座男為什麼會弄丟了真愛？">十二星座男為什麼會弄丟了真愛？</a>
# </div>
# </li>
# </ul>
# </div> </div>
# <div class="bit-3">
# <div class="widget mks_social_widget" id="mks_social_widget-2"><h4 class="widget-title">分享小圖示</h4>
# <ul class="mks_social_widget_ul">
# <li><a class="instagram_ico soc_rounded" href="https://www.instagram.com/coffeearticle/" style="width: 47px; height: 47px; font-size: 16px;line-height:52px;" target="_blank" title="Instagram"><span>instagram</span></a></li>
# <li><a class="facebook_ico soc_rounded" href="https://www.facebook.com/coffeearticle/" style="width: 47px; height: 47px; font-size: 16px;line-height:52px;" target="_blank" title="Facebook"><span>facebook</span></a></li>
# <li><a class="twitter_ico soc_rounded" href="#" style="width: 47px; height: 47px; font-size: 16px;line-height:52px;" target="_blank" title="Twitter"><span>twitter</span></a></li>
# <li><a class="pinterest_ico soc_rounded" href="#" style="width: 47px; height: 47px; font-size: 16px;line-height:52px;" target="_blank" title="Pinterest"><span>pinterest</span></a></li>
# <li><a class="rss_ico soc_rounded" href="#" style="width: 47px; height: 47px; font-size: 16px;line-height:52px;" target="_blank" title="RSS"><span>rss</span></a></li>
# <li><a class="paypal_ico soc_rounded" href="" style="width: 47px; height: 47px; font-size: 16px;line-height:52px;" target="_blank" title="Paypal"><span>paypal</span></a></li>
# </ul>
# </div><div class="widget widget_text" id="text-15"><h4 class="widget-title">授權方式</h4> <div class="textwidget"><a href="http://creativecommons.org/licenses/by-nc-nd/4.0/" rel="license"><img alt="Creative Commons License" src="https://i.creativecommons.org/l/by-nc-nd/4.0/88x31.png" style="border-width:0"/></a><br/>CoffeeArticle封面由 <a href="http://www.coffeearticle.com/" rel="license">一杯咖啡一篇文章</a> 製作，以<a href="http://creativecommons.org/licenses/by-nc-nd/4.0/" rel="license">創用CC 姓名標示-非商業性-禁止改作 4.0 國際授權條款釋出。</a>.</div>
# </div> </div>
# </div>
# </div>
# <div class="container-full site-info">
# <div class="container">
# <div class="vce-wrap-left">
# <p>Copyright © 2017 Coffee Article • All Rights Reserved • Theme by Mizmizi</p> </div>
# <div class="vce-wrap-right">
# <ul class="bottom-nav-menu" id="vce_footer_menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-24474" id="menu-item-24474"><a href="http://www.coffeearticle.com/contact">Contact</a></li>
# </ul> </div>
# </div>
# </div>
# </footer>
# </div>
# </div>
# <a href="javascript:void(0)" id="back-top"><i class="fa fa-angle-up"></i></a>
# <!-- Popups v1.9.3.2 - https://wordpress.org/plugins/popups/ --><style type="text/css">
# #spu-14959 .spu-close{
# 	font-size: 30px;
# 	color:#666;
# 	text-shadow: 0 1px 0 #fff;
# }
# #spu-14959 .spu-close:hover{
# 	color:#000;
# }
# #spu-14959 {
# 	background-color: #eeeeee;
# 	background-color: rgba(238,238,238,1);
# 	color: #333;
# 	padding: 25px;
# 		border-radius: 0px;
# 	-moz-border-radius: 0px;
# 	-webkit-border-radius: 0px;
# 	-moz-box-shadow:  0px 0px 10px 1px #666;
# 	-webkit-box-shadow:  0px 0px 10px 1px #666;
# 	box-shadow:  0px 0px 10px 1px #666;
# 	width: 400px;
#
# }
# #spu-bg-14959 {
# 	opacity: 0.5;
# 	background-color: #000;
# }
# /*
# * Add custom CSS for this popup
# * Be sure to start your rules with #spu-14959 { } and use !important when needed to override plugin rules
# */</style>
# <div class="spu-bg" id="spu-bg-14959"></div>
# <div class="spu-box spu-centered spu-total- " data-auto-hide="0" data-bgopa="0.5" data-box-id="14959" data-close-on-conversion="1" data-dclose-cookie="40" data-dconvert-cookie="999" data-nclose-cookie="spu_closing_14959" data-nconvert-cookie="spu_conversion_14959" data-spuanimation="fade" data-test-mode="0" data-total="" data-trigger="percentage" data-trigger-number="50" data-width="400" id="spu-14959" style="left:-99999px !important;right:auto;">
# <div class="spu-content"><p style="text-align: center;"><span style="color: #000000; font-size: 16pt;"><strong><span style="vertical-align: inherit;"><span style="vertical-align: inherit;"><span style="vertical-align: inherit;"><span style="vertical-align: inherit;"><span style="vertical-align: inherit;"><span style="vertical-align: inherit;"><span style="vertical-align: inherit;"><span style="vertical-align: inherit;">想要知道更多文章? !</span></span></span></span></span></span></span></span></strong></span></p>
# <p style="text-align: center;"><span style="color: #000000; font-size: 16pt;"><strong>趕快按個讚，加入我們的專頁吧!</strong></span></p>
# <p><iframe frameborder="0" height="213" scrolling="no" src="https://www.facebook.com/plugins/page.php?href=https%3A%2F%2Fwww.facebook.com%2Fcoffeearticle%2F&amp;tabs&amp;width=340&amp;height=213&amp;small_header=false&amp;adapt_container_width=true&amp;hide_cover=false&amp;show_facepile=true&amp;appId=247236052366034" style="border: none; overflow: hidden;" width="340"></iframe></p>
# </div>
# <span class="spu-close spu-close-popup top_right"><i class="spu-icon spu-icon-close"></i></span>
# <span class="spu-timer"></span>
# </div>
# <!-- / Popups Box -->
# <div class=" fb_reset" id="fb-root"></div><script>
# 		var advanced_ads_ga_UID = false;
# 		var advanced_ads_ga_anonymIP = true;
# advanced_ads_check_adblocker=function(t){function e(t){(window.requestAnimationFrame||window.mozRequestAnimationFrame||window.webkitRequestAnimationFrame||function(t){return setTimeout(t,16)}).call(window,t)}var n=[],a=null;return e(function(){var t=document.createElement("div");t.innerHTML="&nbsp;",t.setAttribute("class","ad_unit ad-unit text-ad text_ad pub_300x250"),t.setAttribute("style","width: 1px !important; height: 1px !important; position: absolute !important; left: 0px !important; top: 0px !important; overflow: hidden !important;"),document.body.appendChild(t),e(function(){var e=window.getComputedStyle&&window.getComputedStyle(t),o=e&&e.getPropertyValue("-moz-binding");a=e&&"none"===e.getPropertyValue("display")||"string"==typeof o&&-1!==o.indexOf("about:");for(var i=0;i<n.length;i++)n[i](a);n=[]})}),function(t){if(null===a)return void n.push(t);t(a)}}(),function(){var t=function(t,e){this.name=t,this.UID=e,this.analyticsObject=null;var n=this,a={hitType:"event",eventCategory:"Advanced Ads",eventAction:"AdBlock",eventLabel:"Yes",nonInteraction:!0,transport:"beacon"};this.analyticsObject="string"==typeof GoogleAnalyticsObject&&"function"==typeof window[GoogleAnalyticsObject]&&window[GoogleAnalyticsObject],!1===this.analyticsObject?(!function(t,e,n,a,o,i,d){t.GoogleAnalyticsObject=o,t[o]=t[o]||function(){(t[o].q=t[o].q||[]).push(arguments)},t[o].l=1*new Date,i=e.createElement(n),d=e.getElementsByTagName(n)[0],i.async=1,i.src="https://www.google-analytics.com/analytics.js",d.parentNode.insertBefore(i,d)}(window,document,"script",0,"_advads_ga"),_advads_ga("create",n.UID,"auto",this.name),advanced_ads_ga_anonymIP&&_advads_ga("set","anonymizeIp",!0),_advads_ga(n.name+".send",a)):(window.console&&window.console.log("Advanced Ads Analytics >> using other's variable named `"+GoogleAnalyticsObject+"`"),window[GoogleAnalyticsObject]("create",n.UID,"auto",this.name),window[GoogleAnalyticsObject]("set","anonymizeIp",!0),window[GoogleAnalyticsObject](n.name+".send",a))};advanced_ads_check_adblocker(function(e){e&&"string"==typeof advanced_ads_ga_UID&&advanced_ads_ga_UID&&new t("advadsTracker",advanced_ads_ga_UID)})}();
# 		</script><script type="text/javascript">
# disableSelection(document.body)
# </script>
# <noscript><img alt="facebook_pixel" height="1" src="https://www.facebook.com/tr?id=369878790102412&amp;ev=PageView&amp;noscript=1&amp;cd[domain]=www.coffeearticle.com" style="display: none;" width="1"/></noscript><noscript><img alt="facebook_pixel" height="1" src="https://www.facebook.com/tr?id=369878790102412&amp;ev=造訪網站5以上&amp;noscript=1&amp;cd[post_type]=category&amp;cd[content_name]=%E5%BF%83%E9%9D%88%E9%9B%9E%E6%B9%AF&amp;cd[post_id]=16&amp;cd[domain]=www.coffeearticle.com" style="display: none;" width="1"/></noscript>
# <script type="text/javascript">
# 		/* <![CDATA[ */
# 		var pys_edd_ajax_events = [];
# 		/* ]]> */
# 		</script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var spuvar = {"is_admin":"","disable_style":"","ajax_mode":"","ajax_url":"http:\/\/www.coffeearticle.com\/wp-admin\/admin-ajax.php","ajax_mode_url":"http:\/\/www.coffeearticle.com\/?spu_action=spu_load&lang=","pid":"16","is_front_page":"","is_category":"1","site_url":"http:\/\/www.coffeearticle.com","is_archive":"1","is_search":"","is_preview":"","seconds_confirmation_close":"5"};
# var spuvar_social = [];
# /* ]]> */
# </script>
# <script src="http://www.coffeearticle.com/wp-content/plugins/popups/public/assets/js/public.js?ver=1.9.3.2" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var vce_js_settings = {"sticky_header":"1","sticky_header_offset":"700","sticky_header_logo":"","logo":"http:\/\/www.coffeearticle.com\/wp-content\/uploads\/2018\/06\/\u672a\u547d\u540d-1-01.png","logo_retina":"","logo_mobile":"","logo_mobile_retina":"","rtl_mode":"0","ajax_url":"http:\/\/www.coffeearticle.com\/wp-admin\/admin-ajax.php","ajax_mega_menu":"1","mega_menu_slider":"","mega_menu_subcats":"","lay_fa_grid_center":"","full_slider_autoplay":"","grid_slider_autoplay":"","grid_big_slider_autoplay":"","fa_big_opacity":{"1":"0.5","2":"0.7"},"top_bar_mobile":"1","top_bar_mobile_group":"","top_bar_more_link":"More"};
# /* ]]> */
# </script>
# <script src="http://www.coffeearticle.com/wp-content/themes/voice/js/min.js?ver=2.7" type="text/javascript"></script>
# <script src="http://www.coffeearticle.com/wp-includes/js/wp-embed.min.js?ver=4.9.8" type="text/javascript"></script>
# </body>
# </html>
# <!-- Dynamic page generated in 1.830 seconds. -->
# /home/wonderful/.virtualenvs/mario_venv/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /usr/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
import requests
from bs4 import BeautifulSoup as BS4
html = 'http://www.coffeearticle.com/archives/category/心靈雞湯'
headers = {'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1"}
re = requests.get(html, headers = headers)
soup = BS4(re.text)
print(soup.find_all(class_='meta-image'))
# Out:
# [<div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27902" title="成熟的人，看誰都順眼！">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-13-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-13-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-13-150x79.jpg 150w" width="375"/> </a>
# </div>, <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27730" title="最痛的結局，就是人走了，感情還在">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-3-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-3-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-3-150x79.jpg 150w" width="375"/> </a>
# </div>, <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27725" title="一輩子不容易，惟有擁有這10種心態，才能活得簡單快樂">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-7-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-7-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-7-150x79.jpg 150w" width="375"/> </a>
# </div>, <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27687" title="寫給漸漸老去的自己">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-04-150x79.jpg 150w" width="375"/> </a>
# </div>, <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27599" title="懂事的人最委屈，一定要看看的">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/09/封面-09-150x79.jpg 150w" width="375"/> </a>
# </div>, <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27570" title="低調做人，你的路會越走越穩健">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-02-4-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-02-4-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-02-4-150x79.jpg 150w" width="375"/> </a>
# </div>, <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27554" title="一輩子真的好難….">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-04-30-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-04-30-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-04-30-150x79.jpg 150w" width="375"/> </a>
# </div>, <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27483" title="你越覺得你好運，你就越容易吸引到對的人">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-84-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-84-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-84-150x79.jpg 150w" width="375"/> </a>
# </div>, <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27475" title="懂得感恩，才有一切">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-83-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-83-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-83-150x79.jpg 150w" width="375"/> </a>
# </div>, <div class="meta-image">
# <a href="http://www.coffeearticle.com/archives/27469" title="從前的我，現在的我（讀到心酸）">
# <img alt="" class="attachment-vce-lay-b size-vce-lay-b wp-post-image" height="195" sizes="(max-width: 375px) 100vw, 375px" src="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-82-375x195.jpg" srcset="http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-82-375x195.jpg 375w, http://www.coffeearticle.com/wp-content/uploads/2018/08/封面-09-82-150x79.jpg 150w" width="375"/> </a>
# </div>]
# /home/wonderful/.virtualenvs/mario_venv/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /usr/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
import requests
from bs4 import BeautifulSoup as BS4
html = 'http://www.coffeearticle.com/archives/category/心靈雞湯'
headers = {'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1"}
re = requests.get(html, headers = headers)
soup = BS4(re.text)
for i in soup.find_all(class_='meta-image'):
    print(i.a['title'])
# Out:
# 成熟的人，看誰都順眼！
# 最痛的結局，就是人走了，感情還在
# 一輩子不容易，惟有擁有這10種心態，才能活得簡單快樂
# 寫給漸漸老去的自己
# 懂事的人最委屈，一定要看看的
# 低調做人，你的路會越走越穩健
# 一輩子真的好難….
# 你越覺得你好運，你就越容易吸引到對的人
# 懂得感恩，才有一切
# 從前的我，現在的我（讀到心酸）
# /home/wonderful/.virtualenvs/mario_venv/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /usr/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
import requests
from bs4 import BeautifulSoup as BS4
html = 'http://www.coffeearticle.com/archives/category/心靈雞湯'
pages = '/page/'
num = 1
headers = {'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1"}
re = requests.get(html+pages+str(num), headers = headers)
soup = BS4(re.text)
for i in soup.find_all(class_='meta-image'):
    print(i.a['title'])
# Out:
# 成熟的人，看誰都順眼！
# 最痛的結局，就是人走了，感情還在
# 一輩子不容易，惟有擁有這10種心態，才能活得簡單快樂
# 寫給漸漸老去的自己
# 懂事的人最委屈，一定要看看的
# 低調做人，你的路會越走越穩健
# 一輩子真的好難….
# 你越覺得你好運，你就越容易吸引到對的人
# 懂得感恩，才有一切
# 從前的我，現在的我（讀到心酸）
# /home/wonderful/.virtualenvs/mario_venv/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /usr/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
import requests
from bs4 import BeautifulSoup as BS4
html = 'http://www.coffeearticle.com/archives/category/心靈雞湯'
pages = '/page/'
num = 1
headers = {'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1"}
for i in reversed(range(1,5)):
    print(' ')
    print('目前頁數:',i)
    re = requests.get(html+pages+str(i), headers = headers)
    soup = BS4(re.text)
    for i in soup.find_all(class_='meta-image'):
        print(i.a['title'])
# Out:
#
# 目前頁數: 4
# /home/wonderful/.virtualenvs/mario_venv/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /usr/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# 生活順其自然，老天自有安排
# 做人要真（深度好文）
# 不隨意評價別人，是一種修養；不活在別人的評價里，也是一種修行！
# 人生長路漫漫，且行且珍惜。
# 逼出來的堅強，忍出來的性格！
# 心寬是福，看淡是樂（寫的真好）
# 轉變一下思維，就可使人絕處逢生
# 有格局的聰明人：彎腰不是認輸，而是為了拾起 丟掉的幸福！
# 累了，就放空自己
# 人活多久，吃多少，穿多好，富貴還是貧窮，命裡早已註定
#
# 目前頁數: 3
# 有一種安全感，叫靠自己
# 人怎麼待我，我就怎麼待人！
# 真正聰明人，從不吵架 （深度好文）
# 找一個和你頻率相同的人
# 小時候，幸福很簡單；長大了，簡單很幸福
# 心累 （寫的真好）
# 站在人群，我毫不起眼；活在世上，我不玩心眼(送給簡單正直的你)
# 對自己好點，別活得太累了
# 那些沉默的人，看似很平凡，往往是「狠角色」！
# 不要狠心傷害，真心在乎你的人！
#
# 目前頁數: 2
# 目中有人才有路，心中有愛才有度
# 把一切看淡，心就不累了
# 即使老了，也要老的漂亮
# 一輩子，什麼最重要？（句句在理）
# 來時一絲不掛，去時一縷青煙，人就這麼簡單
# 有些心事，無人能懂..
# 成長是一個很痛的名詞，時間能看清一切！
# 有些滄桑，自己懂就好
# 心裡委屈，想要發洩時，看看這5句話，你會好受很多！
# 自己的人生，自己決定！尤其是「女人」做不了公主，就做自己的女王！
#
# 目前頁數: 1
# 成熟的人，看誰都順眼！
# 最痛的結局，就是人走了，感情還在
# 一輩子不容易，惟有擁有這10種心態，才能活得簡單快樂
# 寫給漸漸老去的自己
# 懂事的人最委屈，一定要看看的
# 低調做人，你的路會越走越穩健
# 一輩子真的好難….
# 你越覺得你好運，你就越容易吸引到對的人
# 懂得感恩，才有一切
# 從前的我，現在的我（讀到心酸）
